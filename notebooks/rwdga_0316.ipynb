# %% [markdown]
# # Setup

# %%
# import
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# FILE PATH to load or save
## featurized trajs
## EMUS PMF

# Data organization

# %%
# State def

# %%
# Basis construction (for change of measure)

# %% [markdown]
# # Maximum Entropy principle

# %% [markdown]
# # DGA

# %%
# Basis construction (for committor)

# %%
# Change of measure

# %%
# Committor

# %%
# Reesult
